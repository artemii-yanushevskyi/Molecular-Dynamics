# %%
# %matplotlib inline

import numpy as np
from numpy.random import random
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-fcc55a394c80> in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2
#       3 import numpy as np
#       4 from numpy.random import random
#       5 import matplotlib.pyplot as plt
#
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2285                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2286             with self.builtin_trap:
# -> 2287                 result = fn(*args,**kwargs)
#    2288             return result
#    2289
#
# </anaconda3/lib/python3.6/site-packages/decorator.py:decorator-gen-107> in matplotlib(self, line)
#
# /anaconda3/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
# ...

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots()

ax.set_xlim(( 0, 2))
ax.set_ylim((-2, 2))

line, = ax.plot([], [], lw=2)

# %%
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)

# %%
# animation function. This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return (line,)

# %%
# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)

# %%
HTML(anim.to_html5_video()) #!conda install -c conda-forge ffmpeg

# %% [markdown]
# # MD Model

# %%
class Vector2d:
    def __init__(self, coords=np.random.random(2)):
        self._coords = np.array(coords)
    
    def __str__(self):
        return '2 dim vector, ({}, {})'.format(self.x, self.y)
    
    def __repr__(self):
        return '2 dim vector, ({}, {}) __repr__'.format(self.x, self.y)
    
    x = property()

    def get_x(self):
        return self._coords[0]
    
    def set_x(self, value):
        self._coords[0] = value
        
    # assign fget
    x = x.getter(get_x)
    # assign fset
    x = x.setter(set_x)
    
    y = property()

    def get_y(self):
        return self._coords[1]
    
    def set_y(self, value):
        self._coords[1] = value
        
    # assign fget
    y = y.getter(get_y)
    # assign fset
    y = y.setter(set_y)
    
    def __add__(self, other):
        return Vector2d(self._coords + other._coords)

# %%
class Environment:
    def __init__(self, x=1, y=1):
        self.x = x
        self.y = y


class Atom:
    def __init__(self, weight, r=None, v=None, a=None):
        ''' Initialize r, v and a with random vectors if nothing is specified'''
        self.weight = weight
        
        if r == None:
            self.r = Vector2d()
        else:
            self.r = Vector2d(coords)
        
        if v == None:
            self.v = Vector2d()
        else:
            self.v = Vector2d(coords)
            
        if a == None:
            self.a = Vector2d()
        else:
            self.a = Vector2d(coords)

# %%
class MDModel:
    def __init__(self, environment):
        self.environment = environment
        self.mol = self.make_molecules()
        self.time = 0
        self.dt = 1
        self.cyles_num = 400
        self.u = 0 # energy
    
    def leapfrog1(self):
        
    def leapfrog2(self):
        
    def boundaries(self):
        
    def forces(self):
        dr = Vector2()
        
        for m in mol:
            m.a.x, m.a.y = 0, 0
        
        uSum = 0
        for i in range(20 - 1):
            for j in range(i + 1, 20):
                dr.x = mol[i].r.x - mol[j].r.x
                dr.y = mol[i].r.y - mol[j].r.y
            if dr.x >= 0.5 * environment.x
                dr.x -= environment.x
            elif dr.x < -0.5 * environment.x:
                dr.x += environment.x
            if dr.y >= 0.5 * environment.y:
                dr.y -= environment.y
            elif dr.y < -0.5 * environment.y:
                dr.y += environment.y
        
            rr = dr.x * dr.x + dr.y * dr.y;

            if rr < np.infty:
                rri = 1/rr
                rri3 = rri * rri * rri
                fcVal = 48*rri3*(rri3-0.5)*rri;

                mol[i].ra.x += fcVal * dr.x
                mol[i].ra.y += fcVal * dr.y;
                mol[j].ra.x -= fcVal * dr.x;
                mol[j].ra.y -= fcVal * dr.y;

                uSum += 4*rri3*(rri3 - 1) + 1
            
            self.u = uSum
        
    def single_step(self):
        self.time += self.dt
        self.leapfrog1()
        self.boundaries()
        self.forces()
        sefl.leapfrog2()        

    def loop(self):
        pass
    
    def make_molecules(self):
        atoms = [Atom(0.1) for i in range(20)]
        return atoms

# %%
v = Vector2d()
u = Vector2d()

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)

# Create random data with numpy
import numpy as np

N = 1000
random_x = np.random.randn(N)
random_y = np.random.randn(N)

# random_x = [a.x for a in atoms]
# random_y = [a.y for a in atoms]

# Create a trace
trace = go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers'
)

data = [trace]

# Plot and embed in ipython notebook!
iplot(data)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# ...
